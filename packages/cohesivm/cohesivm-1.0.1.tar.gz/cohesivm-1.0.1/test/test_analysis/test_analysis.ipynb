# %%
# %matplotlib inline
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.insert(1, module_path)
import importlib
import numpy as np
from cohesivm import analysis
_ = importlib.reload(analysis)

# %%
result_map = np.array([[0, 1], [np.nan, 5]])
analysis.plot_result_map(result_map, title='Test')
