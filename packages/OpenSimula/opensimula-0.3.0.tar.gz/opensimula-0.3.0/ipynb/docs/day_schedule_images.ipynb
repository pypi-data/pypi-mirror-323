# %%
import matplotlib.pyplot as plt
import numpy as np

# make data
x = [0,3,4,24]
y = [10,20,15,10]

# plot
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)
plt.xlim(0,24)
plt.ylim(0,22)
plt.grid()
plt.xticks(np.arange(0,24))

plt.show()
