# %% [markdown]
# ### You must initialize the software each time you use     this notebook.
#  1. First, check that the notebook is "Trusted" by looking     near the right of the Jupyter toolbars. If the notebook is not     trusted you need to click on the "not trusted" button and trust the mnotebook. **You should only trust notebooks that come from a *trusted source*, such as the class website.**
#  2. The cell immediately below contains code that loads the software modules necessary for this notebook to run. It also collects some bookkeeping information that can be used for troubleshooting. **You must run this cell each time you use the notebook or later cells may not work.**
#  3. If you doing calculations that depend on using variables passed from calculations done the previous time the notebook was opened, you will need to run those previous cells to redefine the variables.
#  4. *DO NOT run cells that contain plot displays of live data collection, as that will restart the data collection.* You can reload data collected from the `.csv` files  written for each collection run. Ideally you would do this in a new notebook.

# %%
# If no data table appears in the output of this cell, run the cell to display the table.

from IPython.display import HTML
display(HTML('<div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720211815327"}\'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720211815327"}\'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720211815327"}\'title="Save the updated data table.">Save Table</button></div><table class="jp-input_table" id="it_1720211815327" style = "min-width:80%;"><caption class="jp-input_table" style="font-weight:bold;font-size:1.5em;color:darkkhaki;text-align:left;">Table 1: 0.7.0rc1 test</caption><tbody> <tr class="jp-input_table r0">  <th class="jp-input_table r0 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"></th><th class="jp-input_table r0 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">Col_0</span></th> </tr> <tr class="jp-input_table r1"><th class="jp-input_table r1 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">0</span></th>  <td class="jp-input_table r1 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_data_cell">New entry</span></td> </tr></tbody></table></div>'))
# Out:
# <div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720211815327"}'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720211815327"}'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-i
# ...

# %%
from ipylab import JupyterFrontEnd

# %%
app = JupyterFrontEnd()

# %%
app.version
# Out:
# '4.2.3'

# %%
app.commands.list_commands()
# Out:
# ['mathjax:clipboard',
#  'mathjax:scale',
#  'apputils:activate-command-palette',
#  'apputils:print',
#  'codemirror:delete-line',
#  'codemirror:toggle-block-comment',
#  'codemirror:toggle-comment',
#  'codemirror:select-next-occurrence',
#  'shortcuts:edit-keybinding',
#  'shortcuts:delete-keybinding',
#  'shortcuts:add-keybinding',
#  'shortcuts:toggle-selectors',
#  'shortcuts:reset-all',
#  'tooltip:dismiss',
#  'running:kernel-new-console',
#  'running:kernel-new-notebook',
#  'running:kernel-open-session',
#  'running:kernel-shut-down',
#  'apputils:change-theme',
#  'apputils:change-light-theme',
#  'apputils:change-dark-theme',
#  'apputils:adaptive-theme',
#  'apputils:theme-scrollbars',
#  'apputils:change-font',
#  'apputils:incr-font-size',
#  'apputils:decr-font-size',
#  '__internal:context-menu-info',
#  'application:close',
#  'application:close-other-tabs',
#  'application:close-right-tabs',
#  'application:activate-next-tab',
# ...

# %%
app.on_ready(print("ready"))
# Out:
# ready
